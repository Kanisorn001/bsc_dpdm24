# %% [markdown]
# <a href="https://colab.research.google.com/github/Kanisorn001/bsc_dpdm24/blob/main/chapter%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import data from diference format

# %%
# prompt: mout drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##CSV

# %%
# prompt: read  /content/drive/MyDrive/bsc_dpdm24_data/tis_name_02122567.csv encoding cp874

import pandas as pd

file_path = '/content/drive/MyDrive/bsc_dpdm24_data/tis_name_02122567.csv'
df = pd.read_csv(file_path, encoding='cp874')
df.head()
# Out:
#    ลำดับ    เลขที่ มอก.                                  ชื่อ มอก. ภาษาไทย  \
# 0      1         2-2525              ขวดแก้วสำหรับเครื่องดื่มประเภทอัดก๊าซ
# 1      2         3-2562                                             น้ำปลา
# 2      3  4 เล่ม 1-2558  หลอดไฟฟ้าไส้ทังสเตนสำหรับใช้ในที่อยู่อาศัยและท...
# 3      4  4 เล่ม 2-2552  วิธีมาตรฐานในการวัดอุณหภูมิที่เพิ่มขึ้นของขั้ว...
# 4      5  4 เล่ม 3-2563  หลอดไฟฟ้าไส้ทังสเตนสำหรับใช้ในที่อยู่อาศัยและท...
#
#                                 ชื่อ มอก. ภาษาอังกฤษ ประเภทมาตรฐาน  \
# 0                        Aerated water glass bottles        ทั่วไป
# 1                                         Fish sauce        ทั่วไป
# 2  Tungsten filament lamps for domestics and simi...        บังคับ
# 3  Standard method of measurement of lamp cap tem...        ทั่วไป
# 4  Tungsten filament lamps for domestics and simi...        ทั่วไป
#
#    กลุ่มผลิตภัณฑ์ ชนิดมาตรฐาน BCG Economy ประกาศกระทรวงฯ วันที่  \
# ...

# %% [markdown]
# ##EXCEL

# %%
# prompt: open excel file for the sheet name x

file_path_excel = '/content/drive/MyDrive/bsc_dpdm24_data/export62_64.xlsx'
sheet_name = 'Export 63'  # Replace 'x' with the actual sheet name

try:
    df_excel = pd.read_excel(file_path_excel, sheet_name=sheet_name)

except FileNotFoundError:
    print(f"Error: File not found at {file_path_excel}")
except ValueError:
    print(f"Error: Sheet '{sheet_name}' not found in the Excel file.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

# %%
 df_excel.head()
# Out:
#    ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 0      2563            1              1022100          1               C62
# 1      2563            1              1022919          0               C62
# 2      2563            1              1022990          0               C62
# 3      2563            1              1023100          0               C62
# 4      2563            1              1023900          0               C62
#
#       คำอธิบายไทย                    คำอธิบาย  น้ำหนัก/ปริมาณสถิติ  \
# 0        โคตัวผู้                 Bullocks                   14736
# 1          อื่น ๆ                       Other                16995
# 2          อื่น ๆ                       Other                  261
# 3  สำหรับทำพันธุ์  Pure-bred breeding animals                 3460
# 4          อื่น ๆ                       Other                 1349
#
#    มูลค่าส่งออกเงินบาท
# 0            265002594
# 1            326112000
# 2              3444000
# ...

# %%
df_excel2 = pd.read_excel(file_path_excel, sheet_name='Export 64',skiprows=2,usecols=[1,2,3,4])

# %%
 df_excel2.head()
# Out:
#    ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ
# 0      2564            1              1012100          0
# 1      2564            1              1012900          0
# 2      2564            1              1022100          1
# 3      2564            1              1022919          0
# 4      2564            1              1023100          0

# %%
df_excel2 = pd.read_excel(file_path_excel, sheet_name='Export 64',skiprows=2,usecols=range(1,10))
df_excel2.head()
# Out:
#    ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 0      2564            1              1012100          0               C62
# 1      2564            1              1012900          0               C62
# 2      2564            1              1022100          1               C62
# 3      2564            1              1022919          0               C62
# 4      2564            1              1023100          0               C62
#
#       คำอธิบายไทย                    คำอธิบาย  น้ำหนัก/ปริมาณสถิติ  \
# 0  สำหรับทำพันธุ์  Pure-bred breeding animals                   44
# 1          อื่น ๆ                       Other                   35
# 2        โคตัวผู้                 Bullocks                    9674
# 3          อื่น ๆ                       Other                10976
# 4  สำหรับทำพันธุ์  Pure-bred breeding animals                 3169
#
#    มูลค่าส่งออกเงินบาท
# 0               196720
# 1               182000
# 2            145263681
# ...

# %%
 df_excel2.tail()
# Out:
#       ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 1373      2564            1             25309090          5               KGM
# 1374      2564            1             25309090         90               KGM
# 1375      2564            1             26011110          0               KGM
# 1376      2564            1             26011190          0               KGM
# 1377      2564            1             26011290          0               KGM
#
#                คำอธิบายไทย                    คำอธิบาย  น้ำหนัก/ปริมาณสถิติ  \
# 1373        แร่ไพโรฟิลไรท์                 Pyrophylite               272000
# 1374                อื่น ๆ                       Other              2109246
# 1375  แร่เฮมาไทต์และหัวแร่  Haematite and concentrates             42930945
# 1376                อื่น ๆ                       Other                    5
# 1377                อื่น ๆ                       Other                   70
#
#       มูลค่าส่งออกเงินบาท
# ...

# %% [markdown]
# ##SHEET

# %%
# prompt: open google sheet https://docs.google.com/spreadsheets/d/1PM6pqwO4viKGPmQIs7EyspVov8Jh4oC6PTleeLoxV6E/edit?gid=1198870188#gid=1198870188

import pandas as pd
from google.colab import auth
auth.authenticate_user()
import gspread
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)

# Replace with your actual Google Sheet URL
spreadsheet_url = 'https://docs.google.com/spreadsheets/d/1PM6pqwO4viKGPmQIs7EyspVov8Jh4oC6PTleeLoxV6E/edit?gid=1198870188#gid=1198870188'

try:
  # Open the Google Sheet by URL
  wb = gc.open_by_url(spreadsheet_url)

  # Select the worksheet (replace 'Sheet1' with your sheet name if different)
  # You can also select a worksheet by index (e.g., wb.get_worksheet(0) for the first sheet)
  worksheet = wb.worksheet('Export 62') #  Replace 'Sheet1' with the actual sheet name

  # Get all values from the sheet
  rows = worksheet.get_all_values()

  # Convert the data to a Pandas DataFrame
  df_sheet = pd.DataFrame.from_records(rows[1:], columns=rows[0])  # Assuming the first row is the header


except gspread.exceptions.SpreadsheetNotFound:
  print(f"Error: Google Sheet not found at {spreadsheet_url}")
except gspread.exceptions.WorksheetNotFound:
  print(f"Error: Worksheet not found in the Google Sheet.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")

# %%
df_sheet.head()
# Out:
#   ปีแม่แบบ เดือนแม่แบบ พิกัดศุลกากร 8 หลัก รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 0     2562           1            01012900       000               C62
# 1     2562           1            01022100       001               C62
# 2     2562           1            01022100       002               C62
# 3     2562           1            01022919       000               C62
# 4     2562           1            01023100       000               C62
#
#       คำอธิบายไทย                    คำอธิบาย น้ำหนัก/ปริมาณสถิติ  \
# 0          อื่น ๆ                       Other                   7
# 1        โคตัวผู้                 Bullocks                   6663
# 2       โคตัวเมีย                        Cows                  36
# 3          อื่น ๆ                       Other               16983
# 4  สำหรับทำพันธุ์  Pure-bred breeding animals                 746
#
#   มูลค่าส่งออกเงินบาท
# 0              105000
# 1           119934000
# 2             2223000
# 3           362443500
# 4            13055000

# %% [markdown]
# ##Json

# %%
# prompt: load Json flie name data_station

import json
import pandas as pd

def load_json_file(file_path):
  """Loads a JSON file and returns its contents as a Python dictionary.

  Args:
      file_path: The path to the JSON file.

  Returns:
      A Python dictionary representing the JSON data, or None if an error occurs.
  """
  try:
    with open(file_path, 'r') as f:
      data = json.load(f)
    return data
  except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
    return None
  except json.JSONDecodeError:
    print(f"Error: Invalid JSON format in {file_path}")
    return None
  except Exception as e:
    print(f"An unexpected error occurred: {e}")
    return None

# Example usage:
file_path = '/content/drive/MyDrive/bsc_dpdm24_data/data_station.json'  # Replace with the actual file path
data = load_json_file(file_path)

if data:
  # Process the JSON data (example: convert to DataFrame)
  try:
    df_json = pd.DataFrame(data)  # Assumes JSON data represents a list of dictionaries or a dictionary of lists
    df_json.head()
  except Exception as e:
    print("Error converting JSON data to DataFrame:", e)
    print("JSON data loaded successfully. Printing raw data:")
data
# Out:
# [{'id': 1,
#   'station_code': 1001,
#   'name': 'กรุงเทพ',
#   'en_name': 'Bangkok',
#   'th_short': 'กท.',
#   'en_short': 'BKK',
#   'chname': '曼谷',
#   'controldivision': 14,
#   'exact_km': '0',
#   'exact_distance': '0',
#   'km': '0',
#   'class': 11,
#   'lat': 13.739277,
#   'long': 100.517391,
#   'active': 1,
#   'giveway': 1,
#   'dual_track': 1,
#   'comment': 'NULL'},
#  {'id': 2,
#   'station_code': 1002,
#   'name': 'ยมราช',
#   'en_name': 'Yommaraj',
#   'th_short': 'ยช.',
#   'en_short': 'YMR',
#   'chname': '勇马拉',
#   'controldivision': 14,
#   'exact_km': 2,
#   'exact_distance': 2,
#   'km': 2,
#   'class': 99,
#   'lat': 0,
#   'long': 0,
#   'active': 1,
#   'giveway': 1,
#   'dual_track': 1,
#   'comment': 'NULL'},
#  {'id': 3,
#   'station_code': 1004,
#   'name': 'สามเสน',
#   'en_name': 'Sam Sen',
#   'th_short': 'สส.',
#   'en_short': 'SAM',
#   'chname': '三森',
#   'controldivision': 14,
#   'exact_km': 5,
#   'exact_distance': 4,
#   'km': 4,
# ...

# %%
# prompt: load Json flie name memo_2298

file_path = '/content/drive/MyDrive/bsc_dpdm24_data/memo_2298.json'  # Replace with the actual file path
data = load_json_file(file_path)

if data:
  # Process the JSON data (example: convert to DataFrame)
  try:
    df_json = pd.DataFrame(data)  # Assumes JSON data represents a list of dictionaries or a dictionary of lists
    df_json.head()
  except Exception as e:
    print("Error converting JSON data to DataFrame:", e)
    print("JSON data loaded successfully. Printing raw data:")
data
# Out:
# {'MemoId': 2298,
#  'DocumentNo': 'REQ-2019-002298',
#  'TemplateId': 1050,
#  'TemplateName': 'แบบฟอร์มเบิกเงินสดย่อย',
#  'ToPerson': 'Mr. Suwittawat Ragsameorwong',
#  'CcPerson': 'Miss Soravee Ritgarunvong',
#  'CreatorId': 8,
#  'CNameTh': 'นางสาวเพิ่มสิน คุณวิสิฏสิริ',
#  'CNameEn': 'Miss Phoemsin Kunwisitsiri',
#  'CPositionId': 16,
#  'CPositionTh': 'ผู้จัดการฝ่ายขาย',
#  'CPositionEn': 'Account Manager',
#  'CDepartmentId': 4,
#  'CDepartmentTh': 'Management',
#  'CDepartmentEn': 'Management',
#  'CDivisionId': None,
#  'CDivisionTh': None,
#  'CDivisionEn': None,
#  'RequesterId': 8,
#  'RNameTh': 'นางสาวเพิ่มสิน คุณวิสิฏสิริ',
#  'RNameEn': 'Miss Phoemsin Kunwisitsiri',
#  'RPositionId': 16,
#  'RPositionTh': 'ผู้จัดการฝ่ายขาย',
#  'RPositionEn': 'Account Manager',
#  'RDepartmentId': 4,
#  'RDepartmentTh': 'Management',
#  'RDepartmentEn': 'Management',
#  'RDivisionId': None,
#  'RDivisionTh': None,
#  'RDivisionEn': None,
#  'MemoSubject': 'เบิกเงินสดย่อย',
# ...

# %%
import json

# Define the file path
file_path = '/content/drive/MyDrive/bsc_dpdm24_data/memo_2298.json'

# Open the file in read mode ('r')
with open(file_path, 'r') as f:
    # Load the JSON data from the file
    json_2293 = json.load(f)

# The file is automatically closed when you exit the 'with' block

# %%
json_2293
# Out:
# {'MemoId': 2298,
#  'DocumentNo': 'REQ-2019-002298',
#  'TemplateId': 1050,
#  'TemplateName': 'แบบฟอร์มเบิกเงินสดย่อย',
#  'ToPerson': 'Mr. Suwittawat Ragsameorwong',
#  'CcPerson': 'Miss Soravee Ritgarunvong',
#  'CreatorId': 8,
#  'CNameTh': 'นางสาวเพิ่มสิน คุณวิสิฏสิริ',
#  'CNameEn': 'Miss Phoemsin Kunwisitsiri',
#  'CPositionId': 16,
#  'CPositionTh': 'ผู้จัดการฝ่ายขาย',
#  'CPositionEn': 'Account Manager',
#  'CDepartmentId': 4,
#  'CDepartmentTh': 'Management',
#  'CDepartmentEn': 'Management',
#  'CDivisionId': None,
#  'CDivisionTh': None,
#  'CDivisionEn': None,
#  'RequesterId': 8,
#  'RNameTh': 'นางสาวเพิ่มสิน คุณวิสิฏสิริ',
#  'RNameEn': 'Miss Phoemsin Kunwisitsiri',
#  'RPositionId': 16,
#  'RPositionTh': 'ผู้จัดการฝ่ายขาย',
#  'RPositionEn': 'Account Manager',
#  'RDepartmentId': 4,
#  'RDepartmentTh': 'Management',
#  'RDepartmentEn': 'Management',
#  'RDivisionId': None,
#  'RDivisionTh': None,
#  'RDivisionEn': None,
#  'MemoSubject': 'เบิกเงินสดย่อย',
# ...

# %% [markdown]
# quizz 3

# %%
# prompt: print ActorName เเละ ActionProcess ของ ActionHistory เเรก จาก json_2293

print(json_2293['ActionHistory'][0]['ActorName'])
print(json_2293['ActionHistory'][0]['ActionProcess'])
# Out:
# นางสาวเพิ่มสิน คุณวิสิฏสิริ
# submit

# %% [markdown]
# #Distance

# %%
# prompt: build pd dataframe from[[1,2],[-1,4].[0,3],[-3,-2]]

import pandas as pd

data = [[1, 2], [-1, 4], [0, 3], [-3, -2]]
df = pd.DataFrame(data, columns=['X1', 'X2'])
df
# Out:
#    X1  X2
# 0   1   2
# 1  -1   4
# 2   0   3
# 3  -3  -2

# %%
# prompt: draw scatter plot of the df,draw bold line X1 and X2 axes

import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with 'X1' and 'X2' columns

plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.scatter(df['X1'], df['X2'],c='r')
plt.xlabel("X1", fontweight='bold')
plt.ylabel("X2", fontweight='bold')
plt.plot([-3,1],[0,0], color='black', linewidth=2)
plt.plot([0,0],[-2,4], color='black', linewidth=2)
plt.title("Scatter Plot of X1 vs X2")
plt.grid(True)
plt.show()

# %%
# prompt: calculate distance matrix of the df

from scipy.spatial.distance import pdist, squareform

# Calculate the pairwise distances between all rows in the DataFrame
distances = pdist(df[['X1', 'X2']])

# Convert the condensed distance matrix to a square distance matrix
distance_matrix = squareform(distances)

distance_matrix
# Out:
# array([[0.        , 2.82842712, 1.41421356, 5.65685425],
#        [2.82842712, 0.        , 1.41421356, 6.32455532],
#        [1.41421356, 1.41421356, 0.        , 5.83095189],
#        [5.65685425, 6.32455532, 5.83095189, 0.        ]])

# %%
# prompt: calculate distance matrix of the df use L1-norm

from scipy.spatial.distance import pdist, squareform

# Calculate the pairwise distances between all rows in the DataFrame using the L1 norm (Manhattan distance)
distances = pdist(df[['X1', 'X2']], metric='cityblock')

# Convert the condensed distance matrix to a square distance matrix
distance_matrix = squareform(distances)

distance_matrix
# Out:
# array([[0., 4., 2., 8.],
#        [4., 0., 2., 8.],
#        [2., 2., 0., 8.],
#        [8., 8., 8., 0.]])

# %%
data = [[1, 200], [-2, 400], [0, 300], [-3, -200]]
df2 = pd.DataFrame(data, columns=['X1', 'X2'])
df2

plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.scatter(df2['X1'], df2['X2'],c='r')
plt.xlabel("X1", fontweight='bold')
plt.ylabel("X2", fontweight='bold')
plt.plot([-3,10],[0,0], color='black', linewidth=2)
plt.plot([0,0],[-2,40], color='black', linewidth=2)
plt.title("Scatter Plot of X1 vs X2")
plt.grid(True)
plt.show()

# %% [markdown]
# #Normalization (Z-score & Min-Max normalization)

# %%
# prompt: plot histogram of df2 X1

import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.hist(df2['X1'], bins=10, edgecolor='black')  # Adjust bins as needed
plt.xlabel("X1")
plt.ylabel("Frequency")
plt.title("Histogram of X1")
plt.grid(True)
plt.show()

# %%
# prompt: plot histogram of df2 X2

import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.hist(df2['X2'], bins=10, edgecolor='black')  # Adjust bins as needed
plt.xlabel("X2")
plt.ylabel("Frequency")
plt.title("Histogram of X2")
plt.grid(True)
plt.show()

# %% [markdown]
# ##Z-score

# %%
# prompt: calculate z-score for df2

from scipy.stats import zscore

# Calculate z-scores for all columns in df2
df2_zscore = df2.apply(zscore)

df2_zscore
# Out:
#          X1        X2
# 0  1.264911  0.109764
# 1 -0.632456  0.987878
# 2  0.632456  0.548821
# 3 -1.264911 -1.646464

# %%
# prompt: do min-max normalization for the df2 for each column separatery

# Min-Max normalization for each column of df2
df2_min_max = df2.copy()  # Create a copy to avoid modifying the original DataFrame

for column in df2.columns:
    min_val = df2[column].min()
    max_val = df2[column].max()
    df2_min_max[column] = (df2[column] - min_val) / (max_val - min_val)

df2_min_max
# Out:
#      X1        X2
# 0  1.00  0.666667
# 1  0.25  1.000000
# 2  0.75  0.833333
# 3  0.00  0.000000
